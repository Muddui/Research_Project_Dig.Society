# %%
import pandas as pd
import random
import numpy as np
import stopwords
import requests

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

import gensim
import gensim.downloader as api
from gensim import corpora
from gensim import models
from gensim.corpora import Dictionary
from gensim.utils import simple_preprocess
from gensim.models import TfidfModel
from gensim.similarities import SparseTermSimilarityMatrix
from gensim.similarities import WordEmbeddingSimilarityIndex

from glob import glob
from dateutil import parser
from tqdm import tqdm
from string import punctuation

import nltk
from nltk.tokenize import TreebankWordTokenizer
nltk.download('stopwords')
from nltk.corpus import stopwords

import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

print(f"gensim version: {gensim.__version__}")




def df_expl (df):
    desc = {"Columns": df.columns, "Missing": df.isna().sum(), "D_Types": df.dtypes, "Shape": df.shape}
    return desc
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mucki\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# gensim version: 4.3.1

# %%
# "booksresults.xlsx" has infrmation from Google Books API replacing missing info (used in CCS2)
books = pd.read_excel("booksresults.xlsx")


# drop all unneccessary coulumns to reduce size
books.drop(['Unnamed: 0', 'price', 'currency',  'published_date', 'ISBN', 'page_count', 'publisher', 'language'], axis=1, inplace=True)

# Convert values to float and drop missing values/duplicates 
books['rating'] = books['rating'].astype(float).round(1)
books['voters'] = books['voters'].astype(float).round(1)  

books.dropna(subset = ["voters", "rating", "description"], inplace = True)
books.drop_duplicates(subset=['title', 'description'], inplace=True)

# Filter by highest ranking/voter ratio
#books = books[books['voters'] >= 10]
books['ratio'] = books['rating'] / books['voters']

books['generes'] = books['generes'].astype(str)
books["generes"] = books["generes"].str.replace(" &amp,", " & ")

genres = books["generes"].unique().tolist()
genres = [g.replace("&amp,", "& ") for g in genres]

books.head()
# Out:
# Index(['Unnamed: 0', 'title', 'author', 'rating', 'voters', 'price',
#        'currency', 'description', 'publisher', 'page_count', 'generes', 'ISBN',
#        'language', 'published_date', 'year'],
#       dtype='object')
#                                               title          author  rating
# 0                        Attack on Titan: Volume 13  Hajime Isayama     4.6  \
# 1  Antiques Roadkill: A Trash 'n' Treasures Mystery   Barbara Allan     3.3
# 2                    The Art of Super Mario Odyssey        Nintendo     3.9
# 3    Getting Away Is Deadly: An Ellie Avery Mystery     Sara Rosett     4.0
# 4         The Painted Man (The Demon Cycle, Book 1)  Peter V. Brett     4.5
#
#    voters                                        description
# 0   428.0  NO SAFE PLACE LEFT At great cost to the Garris...  \
# 1    23.0  Determined to make a new start in her quaint h...
# 2     9.0  Take a globetrotting journey all over the worl...
# 3    10.0  With swollen feet and swelling belly, pregnant...
# 4   577.0  The stunning debut fantasy novel from author P...
#
#                                     generes    year     ratio
# 0                    comics, graphic novels  2014.0  0.010748
# 1  fiction,mystery & detective,cozy,general  2007.0  0.143478
# 2     games & activities,video & electronic  2019.0  0.433333
# 3                                   fiction  2009.0  0.400000
# 4              fiction,fantasy,dark fantasy  2009.0  0.007799

# %%
# Here's a list of the unique genres, useful to check spelling ;)
genres_j = ",".join(genres)
genres_sp = genres_j.split(",")
unique = set(genres_sp)

unique
# Out:
# {' autobiography',
#  ' economics',
#  ' graphic novels',
#  ' mind',
#  ' spirit',
#  '20th century',
#  'accounting',
#  'action & adventure',
#  'amateur sleuth',
#  'assassination',
#  'biography',
#  'biography & autobiography',
#  'body',
#  'bombay (india)',
#  'brain',
#  'budgeting',
#  'business',
#  'business & economics',
#  'classics',
#  'comics',
#  'comics & graphic novels',
#  'communication & social skills',
#  'computers',
#  'contemporary',
#  'corporate finance',
#  'cozy',
#  'crime',
#  'dark fantasy',
#  'dragons & mythical creatures',
#  'drama',
#  'drug couriers',
#  'economics',
#  'electronic commerce',
#  'environmental conservation & protection',
#  'epic',
#  'fairy tales',
#  'fantasy',
#  'fantasy & magic',
#  'fiction',
#  'financial',
#  'folk tales',
#  'games & activities',
#  'gay',
#  'gender studies',
#  'general',
#  'hard-boiled',
#  'history',
#  'horror',
#  'humorous stories',
#  'industries',
#  'juvenile fiction',
#  'leadership',
#  'legends & mythology',
#  'lgbt',
#  'literary',
#  'literary figures',
#  'management',
#  'media tie-in',
#  'medical (incl. patients)',
#  'mentoring & coaching',
#  'military',
#  'modern',
#  'motivation (psychology)',
#  'motivational',
#  'movements',
#  'mystery & detective',
#  'nan',
#  'nature',
#  'neuropsychology',
#  'new business enterprises',
#  'organizational behavior',
#  'personal finance',
#  'personal growth',
#  'personal success',
#  'police procedural',
#  'political ideologies',
#  'political science',
#  'private investigators',
#  'psychoanalysis',
#  'psychology',
#  'public finance',
#  'religion',
#  'science fiction',
#  'self-confidence',
#  'self-help',
#  'self-management',
#  'social science',
#  'success',
#  'superheroes',
#  'supernatural',
#  'suspense',
#  'theory',
#  'thrillers',
#  'time management',
#  'training',
#  'urban',
#  'video & electronic',
#  'women',
#  'women sleuths',
#  'young adult fiction'}

# %%
print(f"The dataset currently contains {books['title'].nunique()} unique titles.\n")
df_expl(books)
# Out:
# The dataset currently contains 229 unique titles.
# {'Columns': Index(['title', 'author', 'rating', 'voters', 'description', 'generes', 'year',
#         'ratio'],
#        dtype='object'),
#  'Missing': title          0
#  author         0
#  rating         0
#  voters         0
#  description    0
#  generes        0
#  year           1
#  ratio          0
#  dtype: int64,
#  'D_Types': title           object
#  author          object
#  rating         float64
#  voters         float64
#  description     object
#  generes         object
#  year           float64
#  ratio          float64
#  dtype: object,
#  'Shape': (230, 8)}

# %%
def by_genre (genre: str, df: pd.DataFrame): # Input the genre (spelled correctly!) and respective DataFrame
    
    if genre in unique:
        subset = df["generes"].str.contains(genre, case=False, na=False) # Create a subset containing the genre
        filtered = df[subset]                                            # Create new dataframe based on subset
    
        filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
        filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible 
    
        print(f"The top 3 books (out of {len(filtered)}) in {genre} are:\n\n{filtered.head(3)}\n\n")
        # Remove the line above if you wanna use the 'filtered'  DataFrame for another filter ;)
        
        return filtered

    else:
        print(f"The genre {genre} is not in the data base. Please pick from the following: \n {unique}")
        
by_genre("action & adventure", books)
# Out:
# The top 3 books (out of 8) in action & adventure are:
#
#                                                  title               author
# 239  A Dance with Dragons: A Song of Ice and Fire: ...  George R. R. Martin  \
# 29                                        Morning Star         Pierce Brown
# 162                                 Thrawn (Star Wars)         Timothy Zahn
#
#      rating  voters                                        description
# 239     4.5  1799.0  #1 NEW YORK TIMES BESTSELLER • THE BOOK BEHIND...  \
# 29      4.8   886.0  #1 NEW YORK TIMES BESTSELLER • Red Rising thri...
# 162     4.7   588.0  NEW YORK TIMES BESTSELLER • In this definitive...
#
#                                         generes    year     ratio
# 239                  fiction,action & adventure  2011.0  0.002501
# 29   fiction,science fiction,action & adventure  2016.0  0.005418
# 162                  fiction,action & adventure  2017.0  0.007993
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible
#                                                  title                author
# 239  A Dance with Dragons: A Song of Ice and Fire: ...   George R. R. Martin  \
# 29                                        Morning Star          Pierce Brown
# 162                                 Thrawn (Star Wars)          Timothy Zahn
# 264  The Shadow Rising: Book Four of 'The Wheel of ...         Robert Jordan
# 456         Wedge's Gamble: Star Wars Legends (X-Wing)  Michael A. Stackpole
# 847                                                 We      Yevgeny Zamyatin
# 217                     Moby Dick. Illustrated edition       Melville Herman
# 36                                            Salvaged        Madeleine Roux
#
#      rating  voters                                        description
# 239     4.5  1799.0  #1 NEW YORK TIMES BESTSELLER • THE BOOK BEHIND...  \
# 29      4.8   886.0  #1 NEW YORK TIMES BESTSELLER • Red Rising thri...
# 162     4.7   588.0  NEW YORK TIMES BESTSELLER • In this definitive...
# 264     4.7   567.0  The Wheel of Time ® is a PBS Great American Re...
# 456     4.5    87.0  Sleek, swift, and deadly, they are the X-wing ...
# 847     4.3    49.0  Yevgeny Zamyatin's We is set in an urban glass...
# 217     5.0     3.0  The story of the novel created by the famous A...
# 36      4.0     1.0  A WOMAN ON THE RUN. A CAPTAIN ADRIFT IN SPACE....
#
#                                         generes    year     ratio
# 239                  fiction,action & adventure  2011.0  0.002501
# 29   fiction,science fiction,action & adventure  2016.0  0.005418
# 162                  fiction,action & adventure  2017.0  0.007993
# 264          fiction,fantasy,action & adventure  2010.0  0.008289
# 456  fiction,science fiction,action & adventure  2011.0  0.051724
# 847  fiction,science fiction,action & adventure  2013.0  0.087755
# 217                  fiction,action & adventure  2018.0  1.666667
# 36   fiction,science fiction,action & adventure  2019.0  4.000000

# %%
'''
I looked over the dataset and those are the most popular genres with enough titles.
Feel free to explore other genres aswell tho ;D
'''

fantasy = by_genre("fantasy", books)
scie_fi = by_genre("science fiction", books)
myst_det = by_genre("mystery & detective", books)
bus_eco = by_genre("business & economics", books)
self_help = by_genre("self-help", books)
# Out:
# The top 3 books (out of 22) in fantasy are:
#
#                                                  title               author
# 69   A Game of Thrones: A Song of Ice and Fire: Boo...  George R. R. Martin  \
# 117  The Name of the Wind: The Kingkiller Chronicle...     Patrick Rothfuss
# 285  Mistborn Trilogy: The Final Empire, The Well o...    Brandon Sanderson
#
#      rating   voters                                        description
# 69      4.6  10650.0  NOW THE ACCLAIMED HBO SERIES GAME OF THRONES—T...  \
# 117     4.3   4683.0  'I have stolen princesses back from sleeping b...
# 285     4.7   2700.0  This discounted ebundle includes: Mistborn: Th...
#
#                    generes    year     ratio
# 69    fiction,fantasy,epic  2003.0  0.000432
# 117  fiction,fantasy,urban  2010.0  0.000918
# 285   fiction,fantasy,epic  2011.0  0.001741
#
#
# The top 3 books (out of 10) in science fiction are:
#
#                                                 title        author  rating
# 29                                       Morning Star  Pierce Brown     4.8  \
# 79  The Weight of Honor (Kings and Sorcerers--Book 3)   Morgan Rice     4.4
# 20                              Sonic the Hedgehog #3     Ian Flynn     4.7
#
#     voters                                        description
# 29   886.0  #1 NEW YORK TIMES BESTSELLER • Red Rising thri...  \
# 79   591.0  “An action packed fantasy sure to please fans ...
# 20   281.0  Sonic and Knuckles team up, and it's just like...
#
#                                        generes    year     ratio
# 29  fiction,science fiction,action & adventure  2016.0  0.005418
# 79             fiction,science fiction,general  2015.0  0.007445
# 20     comics & graphic novels,science fiction  2018.0  0.016726
#
#
# The top 3 books (out of 18) in mystery & detective are:
#
#                                       title              author  rating
# 72           The Memoirs of Sherlock Holmes  Arthur Conan Doyle     4.2  \
# 31                               After Anna           Alex Lake     4.1
# 54  Little Girl Lost: A Lucy Black Thriller    Brian McGilloway     4.0
#
#     voters                                        description
# 72  3316.0  From his rooms in Baker Street, Sherlock Holme...  \
# 31  1633.0  No.1 EBOOK BESTSELLER. A SUNDAY TIMES TOP 10 P...
# 54  1251.0  This New York Times bestseller is perfect for ...
#
#                                               generes    year     ratio
# 72  fiction,mystery & detective,private investigators  2014.0  0.001267
# 31                fiction,mystery & detective,general  2015.0  0.002511
# 54          fiction,mystery & detective,women sleuths  2014.0  0.003197
#
#
# The top 3 books (out of 19) in business & economics are:
#
#                                                  title            author
# 43             How To Win Friends and Influence People     Dale Carnegie  \
# 207  Freakonomics Rev Ed: A Rogue Economist Explore...  Steven D. Levitt
# 229  The Power of Habit: Why We Do What We Do in Li...    Charles Duhigg
#
#      rating  voters                                        description
# 43      4.3  6615.0  You can go after the job you want—and get it!\...  \
# 207     3.8  4532.0  One of the greatest young American thinkers of...
# 229     4.1  4750.0  NEW YORK TIMES BESTSELLER • This instant class...
#
#                                           generes    year     ratio
# 43                business & economics,leadership  2010.0  0.000650
# 207         business & economics,economics,theory  2010.0  0.000838
# 229  business & economics,organizational behavior  2012.0  0.000863
#
#
# The top 3 books (out of 13) in self-help are:
#
#                                                  title        author  rating
# 261                                         The Secret  Rhonda Byrne     4.1  \
# 376  You Are a Badass: How to Stop Doubting Your Gr...   Jen Sincero     4.1
# 213  Awaken the Giant Within: How to Take Immediate...  Tony Robbins     4.6
#
#      voters                                        description
# 261  9403.0  The tenth-anniversary edition of the book that...  \
# 376  1345.0  YOU ARE A BADASS IS THE SELF-HELP BOOK FOR PEO...
# 213   250.0  Wake up and take control of your life! From th...
#
#                                generes    year     ratio
# 261  self-help,personal growth,success  2007.0  0.000436
# 376                  self-help,general  2016.0  0.003048
# 213  self-help,personal growth,success  2007.0  0.018400
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.drop_duplicates(subset=['title', 'description'], inplace=True)
# C:\Users\mucki\AppData\Local\Temp\ipykernel_2436\249220304.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.sort_values(by = 'ratio', inplace = True)               # Sort by ratio, results seem plausible
